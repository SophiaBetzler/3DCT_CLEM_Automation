# %%
# %load_ext autoreload
# %autoreload 2

from tdct.io import load_and_parse_fm_image

#PATH = r"D:\24dec05k-delmic/multichannel-z-stack-Feature-2-Active-001.ome.tiff"
PATH = r"D:\24dec19i-delmic/multichannel-z-stack-after-rough-Feature-1-Active-001.ome.tiff"
from pprint import pprint
img, ddict = load_and_parse_fm_image(PATH)

pprint(ddict)
print(img.shape)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'colours': ['gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray',
#              'gray'],
#  'pixel_size': None,
#  'zstep': None}
# (21, 1275, 1025)

# %%
import tifffile as tff
from ome_types import from_tiff

with tff.TiffReader(PATH) as tif:
    #print(tif.pages[0].tags)
    ome = from_tiff(PATH, validate=False)
    print(ome)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[10], line 6
#       2 from ome_types import from_tiff
#       4 with tff.TiffReader(PATH) as tif:
#       5     #print(tif.pages[0].tags)
# ----> 6     ome = from_tiff(PATH, validate=False)
#       7     print(ome)
#
# File c:\Users\User\miniconda3\envs\openfibsem\lib\site-packages\ome_types\_conversion.py:159, in from_tiff(path, validate, parser_kwargs)
#     144 """Generate an OME object from a TIFF file.
#     145
#     146 Parameters
#    (...)
#     156     will be used.
#     157 """
#     158 xml = tiff2xml(path)
# --> 159 return from_xml(xml, validate=validate, parser_kwargs=parser_kwargs)
#
# File c:\Users\User\miniconda3\envs\openfibsem\lib\site-packages\ome_types\_conversion.py:132, in from_xml(source, validate, parser, parser_kwargs, transformations, warn_on_schema_update)
# ...
